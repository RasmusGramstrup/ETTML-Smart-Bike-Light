# %%
# %pip install scipy
# %pip install numpy
# %pip install matplotlib
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %ls tcp_server\out
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 6ABC-880A
#
#  Directory of c:\Users\rgram\Documents\GitHub\ETTML-Smart-Bike-Light\tcp_server\out
#
# 02-05-2025  08:25    <DIR>          .
# 28-04-2025  14:27    <DIR>          ..
# 01-05-2025  19:55            30.750 bike_01_05.00004.csv
# 01-05-2025  19:57            31.367 bike_01_05.00005.csv
# 01-05-2025  20:00            30.959 bike_01_05.00008.csv
# 01-05-2025  20:00            31.249 bike_01_05.00009.csv
# 01-05-2025  20:01            30.605 bike_01_05.00010.csv
# 01-05-2025  20:01            31.415 bike_01_05.00011.csv
# 01-05-2025  20:01            31.203 bike_01_05.00012.csv
# 01-05-2025  20:02            31.270 bike_01_05.00013.csv
# 01-05-2025  20:02            31.122 bike_01_05.00014.csv
# 01-05-2025  20:02            31.077 bike_01_05.00015.csv
# 01-05-2025  20:04            30.756 bike_01_05.00016.csv
# 01-05-2025  20:05            31.343 bike_01_05.00017.csv
# ...

# %%
import pandas as pd
#import csv, #add headers, timestamp, accX,accY,accZ,gyroX,gyroY,gyroZ,magX,magY,magZ
data = pd.read_csv('tcp_server/out/bike_01_05.Break.00001.csv', skiprows=0, encoding="utf-8")
data.head()
# Out:
#    timestamp  accX  accY  accZ  gyroX  gyroY  gyroZ  magX  magY  magZ
# 0   34351813   0.0   0.0   0.0    0.0   0.00    0.0   0.0   0.0   0.0
# 1   34369547   0.0   0.0   0.0    0.0   0.00    0.0   0.0   0.0   0.0
# 2   34371243   0.0   0.0   0.0    0.0   0.00    0.0   0.0   0.0   0.0
# 3   34379776   0.0   0.0   0.0    0.0   0.00    0.0   0.0   0.0   0.0
# 4   34391255   0.0   0.0   0.0   -0.2   0.36    0.3   0.0   0.0   0.0

# %%
#add columns
data.columns = ['timestamp', 'accX', 'accY', 'accZ', 'gyroX', 'gyroY', 'gyroZ', 'magX', 'magY', 'magZ']
#remove index, sort by timestamp
data = data.set_index('timestamp')
data = data.sort_index()
data.head()
# Out:
#            accX  accY  accZ  gyroX  gyroY  gyroZ  magX  magY  magZ
# timestamp
# 34351813    0.0   0.0   0.0    0.0   0.00    0.0   0.0   0.0   0.0
# 34369547    0.0   0.0   0.0    0.0   0.00    0.0   0.0   0.0   0.0
# 34371243    0.0   0.0   0.0    0.0   0.00    0.0   0.0   0.0   0.0
# 34379776    0.0   0.0   0.0    0.0   0.00    0.0   0.0   0.0   0.0
# 34391255    0.0   0.0   0.0   -0.2   0.36    0.3   0.0   0.0   0.0

# %%
len(data)
# Out:
# 499

# %%
#plot data figsize 12,6
data.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='timestamp'>
