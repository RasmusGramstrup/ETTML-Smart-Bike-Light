# %%
# %pip install scipy
# %pip install numpy
# %pip install matplotlib
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %ls tcp_server\out
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 6ABC-880A
#
#  Directory of c:\Users\rgram\Documents\GitHub\ETTML-Smart-Bike-Light\tcp_server\out
#
# 22-05-2025  15:37    <DIR>          .
# 05-05-2025  18:16    <DIR>          ..
# 05-05-2025  17:44    <DIR>          01_05
# 06-05-2025  11:56    <DIR>          05_05
# 15-05-2025  08:57    <DIR>          15_05
# 22-05-2025  15:37    <DIR>          15_05_2
# 15-05-2025  09:53    <DIR>          15_05_test
# 06-05-2025  11:56    <DIR>          split
#                0 File(s)              0 bytes
#                8 Dir(s)  366.614.548.480 bytes free

# %%
import pandas as pd
import matplotlib.pyplot as plt
#import csv, #add headers, timestamp, accX,accY,accZ,gyroX,gyroY,gyroZ,magX,magY,magZ
data1 = pd.read_csv('tcp_server/out_converted/Right.00001.csv', skiprows=0, encoding="utf-8")
data2 = pd.read_csv('tcp_server/out_converted/Left.00001.csv', skiprows=0, encoding="utf-8")
data3 = pd.read_csv('tcp_server/out_converted/Break.00001.csv', skiprows=0, encoding="utf-8")
data4 = pd.read_csv('tcp_server/out_converted/Straight.00001.csv', skiprows=0, encoding="utf-8")
# data1 = data1.iloc[:,[0, 4, 5, 6]]
data2 = data2.iloc[:,[0, 4, 5, 6]]
data3 = data3.iloc[:,[0, 4, 5, 6]]
data4 = data4.iloc[:,[0, 4, 5, 6]]

data1.head()
# Out:
#    timestamp  accX  accY   accZ  gyroX  gyroY  gyroZ
# 0          7  2.45  2.53   8.85  -0.01   0.00   0.00
# 1         26 -3.68  0.50   6.63  -0.05   0.03  -0.27
# 2         46 -1.99  0.15   8.39  -0.09   0.13  -0.26
# 3         66  2.91 -0.84  13.18  -0.09   0.13  -0.26
# 4         87 -0.42 -1.27  11.26  -0.06   0.09  -0.21

# %%
#add columns
data1.columns = ['timestamp', 'accX', 'accY', 'accZ', 'gyroX', 'gyroY', 'gyroZ']
data2.columns = ['timestamp', 'gyroX', 'gyroY', 'gyroZ']
data3.columns = ['timestamp', 'gyroX', 'gyroY', 'gyroZ']
data4.columns = ['timestamp', 'gyroX', 'gyroY', 'gyroZ']

data1 = data1.set_index('timestamp')
data1 = data1.sort_index()
data1.head()

data2 = data2.set_index('timestamp')
data2 = data2.sort_index()
data2.head()

data3 = data3.set_index('timestamp')
data3 = data3.sort_index()
data3.head()

data4 = data4.set_index('timestamp')
data4 = data4.sort_index()
data4.head()
# Out:
#            gyroX  gyroY  gyroZ
# timestamp
# 6           0.46  -0.10   0.21
# 25         -0.05  -0.01  -0.03
# 46         -0.05  -0.04  -0.04
# 66         -0.09  -0.08  -0.08
# 87         -0.11   0.05  -0.09

# %%
len(data1)
len(data2)
len(data3)
len(data4)
# Out:
# 250

# %%
#plot data figsize 12,6
data1.plot(figsize=(12,6),)

data2.plot(figsize=(12,6))

data3.plot(figsize=(12,6))

data4.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='timestamp'>

# %%
data10 = pd.read_csv('./tcp_server\out/01_05/bike_01_05.00004.csv', skiprows=0, encoding="utf-8")

data10.head()

data10.columns = ['timestamp', 'accX', 'accY', 'accZ', 'gyroX', 'gyroY', 'gyroZ', 'magX', 'magY', 'magZ']


data10 = data10.set_index('timestamp')
data10 = data10.sort_index()
data10.head()


len(data10)

data10.plot(figsize=(12,6),)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\o'
# <>:1: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\rgram\AppData\Local\Temp\ipykernel_45508\3014492631.py:1: SyntaxWarning: invalid escape sequence '\o'
#   data10 = pd.read_csv('./tcp_server\out/01_05/bike_01_05.00004.csv', skiprows=0, encoding="utf-8")
# <Axes: xlabel='timestamp'>

# %%
data10 = pd.read_csv('./tcp_server\out/05_05/bike_05_05.00001.csv', skiprows=0, encoding="utf-8")

data10.head()

data10.columns = ['timestamp','quatI','quatJ','quatK','quatReal']


data10 = data10.set_index('timestamp')
data10 = data10.sort_index()
data10.head()


len(data10)

data10.plot(figsize=(12,6),)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\o'
# <>:1: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\rgram\AppData\Local\Temp\ipykernel_45508\1203745323.py:1: SyntaxWarning: invalid escape sequence '\o'
#   data10 = pd.read_csv('./tcp_server\out/05_05/bike_05_05.00001.csv', skiprows=0, encoding="utf-8")
# <Axes: xlabel='timestamp'>
